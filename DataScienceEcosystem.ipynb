# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.
#
# This notebook provides an overview of essential data science languages, libraries, and tools. It also demonstrates simple arithmetic operations using code cells and outlines the objectives and authorship for this exercise.

# %% [markdown]
# ## Data Science Languages
#
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
#
# - NumPy
# - Pandas
# - Scikit-learn
# - Matplotlib
# - TensorFlow
# - ggplot2
# - dplyr

# %% [markdown]
# ## Data Science Tools
# | Tool Name      | Description                      | Language Supported |
# |----------------|----------------------------------|-------------------|
# | Jupyter Notebook | Interactive coding environment   | Python, R, Julia  |
# | RStudio        | IDE for R programming            | R                 |
# | Apache Spark   | Big data processing framework    | Python, Scala, R  |
# | Tableau        | Data visualization tool          | N/A (GUI based)   |
# | IBM Watson Studio | Cloud-based data science platform | Python, R        |

# %% [markdown]
# ## Examples of Arithmetic Expressions
#
# The following code cells show simple arithmetic operations such as addition and multiplication.

# %%
# Multiply two numbers
a=3
b=4
c=5
print((a*b)+c)
# Out:
# 17

# %%
# Convert minutes to hours
minutes = 200
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %% [markdown]
# ## Objectives
#
# - List popular data science languages
# - Identify commonly used data science libraries and tools
# - Practice basic arithmetic in code cells
# - Learn to format Markdown and code cells in Jupyter Notebook
# - Share the notebook via GitHub

# %% [markdown]
# **Author:** Ravi Kumar Jangir
